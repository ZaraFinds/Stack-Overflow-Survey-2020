# %%
import pandas as pd

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv("survey_results_public.csv", index_col='Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %% [markdown]
# ## Getting the number of rows and columns

# %%
df.shape
# Out:
# (64461, 60)

# %% [markdown]
# ## Changing the settings to display all the columns and rows

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %% [markdown]
# ## Accessing specific rows and columns' data

# %%
df[['LanguageWorkedWith', 'OpSys', 'DevType']]
# Out:
#                                            LanguageWorkedWith        OpSys  \
# Respondent
# 1                                      C#;HTML/CSS;JavaScript      Windows
# 2                                            JavaScript;Swift        MacOS
# 3                                    Objective-C;Python;Swift  Linux-based
# 4                                                         NaN  Linux-based
# 5                                           HTML/CSS;Ruby;SQL      Windows
# ...                                                       ...          ...
# 64858                                                     NaN      Windows
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...          NaN
# 64898                                                     NaN          NaN
# 64925                                                HTML/CSS      Windows
# 65112                         C#;HTML/CSS;Java;JavaScript;SQL      Windows
#
# ...

# %%
df.iloc[[1,2,16,32,45]]
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 2           I am a developer by profession       No   NaN         19      NaN
# 3              I code primarily as a hobby      Yes   NaN         15      NaN
# 17          I am a developer by profession      Yes  25.0         14   Yearly
# 33          I am a developer by profession      Yes  39.0         14  Monthly
# 46          I am a developer by profession      Yes  24.0         14   Yearly
#
#             CompTotal  ConvertedComp             Country  \
# Respondent
# 2                 NaN            NaN      United Kingdom
# 3                 NaN            NaN  Russian Federation
# 17            79000.0        79000.0       United States
# 33             4900.0        63564.0             Belgium
# 46            35000.0        37834.0              France
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 2                 Pound sterling            GBP
# ...

# %%
#Accessing any specific rows and columns
df.loc[[24, 15, 62], ['Hobbyist', 'EdLevel', 'Country']]
# Out:
#            Hobbyist                                            EdLevel  \
# Respondent
# 24              Yes                 Professional degree (JD, MD, etc.)
# 15              Yes       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62               No  Some college/university study without earning ...
#
#                    Country
# Respondent
# 24                 Germany
# 15                  France
# 62          United Kingdom

# %%
df.loc[10:20, 'Country': 'JobSeek']
# Out:
#                    Country          CurrencyDesc CurrencySymbol  \
# Respondent
# 10          United Kingdom        Pound sterling            GBP
# 11          United Kingdom        Pound sterling            GBP
# 12                   Spain         European Euro            EUR
# 13             Netherlands         European Euro            EUR
# 14           United States  United States dollar            USD
# 15                  France                   NaN            NaN
# 16          United Kingdom        Pound sterling            GBP
# 17           United States  United States dollar            USD
# 18           United States  United States dollar            USD
# 19           United States  United States dollar            USD
# 20                   Spain         European Euro            EUR
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 10                                      Microsoft SQL Server
# ...

# %%
# Getting a random sample of a certain column
df['Age'].sample(30)
# Out:
# Respondent
# 20726    28.0
# 52696    31.0
# 51796    44.0
# 63450     NaN
# 10093    41.0
# 43152     NaN
# 60582     NaN
# 22670    27.0
# 11553    37.0
# 62748     NaN
# 56338    26.0
# 696      30.0
# 10364     NaN
# 22487    23.0
# 54751     NaN
# 46673    44.0
# 23004    26.0
# 12799    31.0
# 12373    30.0
# 57376     NaN
# 45863    24.0
# 19149    31.0
# 1142     22.0
# 21949    25.0
# 60570    29.0
# 55948     NaN
# 21720    28.0
# 4945     30.0
# 55555     NaN
# 15228    27.0
# Name: Age, dtype: float64

# %%
df['Hobbyist'].value_counts(normalize=True)
# Out:
# Yes    0.782228
# No     0.217772
# Name: Hobbyist, dtype: float64

# %%
df['Country'].value_counts().head(10).plot(kind='pie')

# %%
df['Country'].value_counts(normalize=True)
# Out:
# United States     0.194609
# India             0.131149
# United Kingdom    0.060807
# Germany           0.060713
# Canada            0.034196
#                     ...
# Gabon             0.000016
# Fiji              0.000016
# Liechtenstein     0.000016
# North Korea       0.000016
# Kiribati          0.000016
# Name: Country, Length: 183, dtype: float64

# %%
df['OpSys'].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: OpSys, dtype: int64

# %% [markdown]
# ## Filtering rows and columns using conditionals

# %% [markdown]
# ### If we want to know the response to the Hobbyist question only in Canada we can write a conditional

# %%
df[df['Country'] == 'Canada'].Hobbyist.value_counts()
# Out:
# Yes    1676
# No      515
# Name: Hobbyist, dtype: int64

# %% [markdown]
# ### Creating a filter for high salary and applying that filter to specific columns

# %%
high_salary = df['ConvertedComp'] > 70000

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ['Canada', 'United States', 'India', 'United Kingdom', 'China']
filt = df['Country'].isin(countries)
df.loc[filt, 'Country']
# Out:
# Respondent
# 2        United Kingdom
# 5         United States
# 7                 India
# 8         United States
# 10       United Kingdom
#               ...
# 62834            Canada
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 27330, dtype: object

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
pyFilt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[pyFilt, ['LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 3                                    Objective-C;Python;Swift            NaN
# 8                                                  Python;SQL       116000.0
# 10                        HTML/CSS;Java;JavaScript;Python;SQL        32315.0
# 13                                        C;JavaScript;Python        38916.0
# 15           Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL            NaN
# ...                                                       ...            ...
# 61561       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...            NaN
# 62391          C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript            NaN
# 63077                 C++;HTML/CSS;Java;JavaScript;Python;SQL            NaN
# 63640       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...            NaN
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...            NaN
#
# [25287 rows x 2 columns]

# %% [markdown]
# ## Updating rows and columns

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %% [markdown]
# ## Sorting data

# %%
df.sort_values(['Country', 'SalaryUSD'], ascending=[True, False])
# Out:
#                                 MainBranch Hobbyist  Age  \
# Respondent
# 62788       I am a developer by profession      Yes  NaN
# 65381       I am a developer by profession       No  NaN
# 65456       I am a developer by profession      Yes  NaN
# 38672       I am a developer by profession       No  NaN
# 28374       I am a developer by profession      Yes  NaN
# ...                                    ...      ...  ...
# 60055                                  NaN       No  NaN
# 61121                                  NaN      Yes  NaN
# 61570                                  NaN       No  NaN
# 61918                                  NaN      Yes  NaN
# 62605                                  NaN       No  NaN
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# 62788                        NaN   Weekly  8.000000e+06  1000000.0
# 65381                          8   Weekly  8.740000e+09  1000000.0
# ...

# %%
df[['Country', 'SalaryUSD']].head(50)
# Out:
#                        Country  SalaryUSD
# Respondent
# 1                      Germany        NaN
# 2               United Kingdom        NaN
# 3           Russian Federation        NaN
# 4                      Albania        NaN
# 5                United States        NaN
# 6                      Germany        NaN
# 7                        India        NaN
# 8                United States   116000.0
# 9                      Tunisia        NaN
# 10              United Kingdom    32315.0
# 11              United Kingdom    40070.0
# 12                       Spain    14268.0
# 13                 Netherlands    38916.0
# 14               United States    66000.0
# 15                      France        NaN
# 16              United Kingdom   108576.0
# 17               United States    79000.0
# 18               United States  1260000.0
# 19               United States    83400.0
# 20                       Spain        NaN
# 21                     Belgium        NaN
# ...

# %% [markdown]
# ### Getting the highest value in a column

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 123     2000000.0
# 125     2000000.0
# 193     2000000.0
# 665     2000000.0
# 699     2000000.0
# 724     2000000.0
# 818     2000000.0
# 986     2000000.0
# 1022    2000000.0
# 1036    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df['Age'].nlargest(10)
# Out:
# Respondent
# 14419    279.0
# 2522      99.0
# 2638      99.0
# 5950      99.0
# 26839     99.0
# 46268     99.0
# 48563     99.0
# 52018     99.0
# 53925     99.0
# 57850     99.0
# Name: Age, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 123                            I am a developer by profession      Yes  26.0
# 125         I am not primarily a developer, but I write co...      Yes  41.0
# 193                            I am a developer by profession      Yes  29.0
# 665                            I am a developer by profession      Yes  24.0
# 699         I am not primarily a developer, but I write co...      Yes  39.0
# 724         I am not primarily a developer, but I write co...      Yes   NaN
# 818         I am not primarily a developer, but I write co...      Yes  40.0
# 986                            I am a developer by profession      Yes  27.0
# 1022                           I am a developer by profession      Yes  34.0
# 1036                           I am a developer by profession      Yes  26.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD        Country  \
# Respondent
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 124                            I am a developer by profession       No  38.0
# 238         I am not primarily a developer, but I write co...      Yes   NaN
# 884                            I am a developer by profession      Yes  41.0
# 1116                           I am a developer by profession      Yes  25.0
# 1278                           I am a developer by profession      Yes  21.0
# 1794                           I am a developer by profession      Yes   NaN
# 2073                           I am a developer by profession      Yes  27.0
# 2196                           I am a developer by profession      Yes   NaN
# 2248                           I am a developer by profession       No   NaN
# 2323                           I am a developer by profession      Yes   NaN
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD              Country  \
# Respondent
# ...

# %% [markdown]
# ## Grouping and aggregating - analyzing and exploring data

# %% [markdown]
# ### Finding the mean, median and mode of a specific column

# %%
df['SalaryUSD'].mean()
# Out:
# 103756.05014961446

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df['SalaryUSD'].mode()
# Out:
# 0    120000.0
# dtype: float64

# %%
df.median()
# Out:
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['UndergradMajor'].count()
# Out:
# 50995

# %%
df['UndergradMajor'].value_counts(normalize=True)
# Out:
# Computer science, computer engineering, or software engineering                   0.619316
# Another engineering discipline (such as civil, electrical, mechanical, etc.)      0.093225
# Information systems, information technology, or system administration             0.079831
# A natural science (such as biology, chemistry, physics, etc.)                     0.043240
# Mathematics or statistics                                                         0.036258
# Web development or web design                                                     0.035082
# A business discipline (such as accounting, finance, marketing, etc.)              0.026963
# A humanities discipline (such as literature, history, philosophy, etc.)           0.019747
# A social science (such as anthropology, psychology, political science, etc.)      0.018296
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)    0.014217
# ...

# %% [markdown]
# ### Grouping by country

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Canada')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 26          I am a developer by profession       No   NaN         12   Yearly
# 32          I am a developer by profession      Yes  31.0         12  Monthly
# 51          I am a developer by profession       No   NaN         10   Yearly
# 66          I am a developer by profession      Yes  21.0          9      NaN
# 75          I am a developer by profession       No   NaN        NaN      NaN
# ...                                    ...      ...   ...        ...      ...
# 19609                                  NaN      Yes   NaN         10      NaN
# 30010                                  NaN      Yes  28.0         16      NaN
# 35616                                  NaN      Yes   NaN        NaN      NaN
# 36174                                  NaN      Yes   NaN        NaN      NaN
# 62834                                  NaN      Yes  17.0         10      NaN
#
# ...

# %%
country_grp['UndergradMajor'].value_counts().head(50)
# Out:
# Country      UndergradMajor
# Afghanistan  Computer science, computer engineering, or software engineering                    30
#              Web development or web design                                                       3
#              Another engineering discipline (such as civil, electrical, mechanical, etc.)        2
#              Information systems, information technology, or system administration               2
#              Mathematics or statistics                                                           2
#              A natural science (such as biology, chemistry, physics, etc.)                       1
# Albania      Computer science, computer engineering, or software engineering                    25
#              Web development or web design                                                       4
#              Information systems, information technology, or system administration               3
# ...

# %%
filt = df['Country'] == 'Canada'
df.loc[filt]['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   1214
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       129
# Information systems, information technology, or system administration               98
# A natural science (such as biology, chemistry, physics, etc.)                       93
# Web development or web design                                                       73
# Mathematics or statistics                                                           68
# A business discipline (such as accounting, finance, marketing, etc.)                40
# A social science (such as anthropology, psychology, political science, etc.)        35
# A humanities discipline (such as literature, history, philosophy, etc.)             31
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      26
# I never declared a major                                                            18
# ...

# %%
# Another way of doing the same thing
country_grp['UndergradMajor'].value_counts().loc['Canada']
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   1214
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       129
# Information systems, information technology, or system administration               98
# A natural science (such as biology, chemistry, physics, etc.)                       93
# Web development or web design                                                       73
# Mathematics or statistics                                                           68
# A business discipline (such as accounting, finance, marketing, etc.)                40
# A social science (such as anthropology, psychology, political science, etc.)        35
# A humanities discipline (such as literature, history, philosophy, etc.)             31
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      26
# I never declared a major                                                            18
# ...

# %%
country_grp['SalaryUSD'].median().loc['Canada']
# Out:
# 68068.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Canada'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 1011

# %% [markdown]
# ### grouping by country and applying a function to find out the number of respondents who use Python in each country

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Gabon                 1
# Fiji                  1
# Liechtenstein         1
# North Korea           1
# Kiribati              1
# Name: Country, Length: 183, dtype: int64

# %%
python_users = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
python_users
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %% [markdown]
# ### Creating a new dataframe with the variables created

# %%
python_df = pd.concat([country_respondents, python_users], axis='columns', sort=False)

# %%
python_df
# Out:
#                 Country  LanguageWorkedWith
# United States     12469                5964
# India              8403                2670
# United Kingdom     3896                1621
# Germany            3890                1712
# Canada             2191                1011
# ...                 ...                 ...
# Gabon                 1                   1
# Fiji                  1                   0
# Liechtenstein         1                   0
# North Korea           1                   0
# Kiribati              1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'KnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                 NumRespondents  KnowsPython
# United States            12469         5964
# India                     8403         2670
# United Kingdom            3896         1621
# Germany                   3890         1712
# Canada                    2191         1011
# ...                        ...          ...
# Gabon                        1            1
# Fiji                         1            0
# Liechtenstein                1            0
# North Korea                  1            0
# Kiribati                     1            0
#
# [183 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['KnowsPython']/python_df['NumRespondents']) * 100

# %%
python_df
# Out:
#                 NumRespondents  KnowsPython  PctKnowsPython
# United States            12469         5964       47.830620
# India                     8403         2670       31.774366
# United Kingdom            3896         1621       41.606776
# Germany                   3890         1712       44.010283
# Canada                    2191         1011       46.143314
# ...                        ...          ...             ...
# Gabon                        1            1      100.000000
# Fiji                         1            0        0.000000
# Liechtenstein                1            0        0.000000
# North Korea                  1            0        0.000000
# Kiribati                     1            0        0.000000
#
# [183 rows x 3 columns]

# %%
python_df.loc['Japan', 'PctKnowsPython']
# Out:
# 44.44444444444444

# %%
python_df.sort_values('PctKnowsPython', ascending=False).head(50)
# Out:
#                                       NumRespondents  KnowsPython  \
# Gabon                                              1            1
# Saint Lucia                                        1            1
# Micronesia, Federated States of...                 1            1
# Montenegro                                        13            9
# Brunei Darussalam                                  3            2
# Guyana                                             5            3
# Swaziland                                          7            4
# Iceland                                           53           28
# Finland                                          349          183
# Uganda                                            81           42
# Burkina Faso                                       6            3
# Jamaica                                           14            7
# Mauritania                                         4            2
# ...

# %% [markdown]
# ## Reading and writing data to different sources

# %% [markdown]
# ### Writing data to CSV

# %%
filt = df['Country'] == 'Canada'
canada_df = df.loc[filt]

# %%
canada_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD Country    CurrencyDesc  \
# Respondent
# 1                  13  Monthly        NaN        NaN  Canada   European Euro
# 2                  19      NaN        NaN        NaN  Canada  Pound sterling
# 3                  15      NaN        NaN        NaN  Canada             NaN
# 4                  18      NaN        NaN        NaN  Canada    Albanian lek
# 5                  16      NaN        NaN        NaN  Canada             NaN
#
# ...

# %%
canada_df.to_csv('modified.csv')

# %% [markdown]
# ### Write dataframe to tsv file

# %%
canada_df.to_csv('modified.tsv', sep='\t')

# %% [markdown]
# ### Write dataframe to excel file

# %%
canada_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('modified.xlsx', index_col='Respondent')
test.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  SalaryUSD Country    CurrencyDesc  \
# Respondent
# 1                  13  Monthly        NaN        NaN  Canada   European Euro
# 2                  19      NaN        NaN        NaN  Canada  Pound sterling
# 3                  15      NaN        NaN        NaN  Canada             NaN
# 4                  18      NaN        NaN        NaN  Canada    Albanian lek
# 5                  16      NaN        NaN        NaN  Canada             NaN
#
# ...

# %% [markdown]
# ### writing the dataframe to json file and making the json file list like

# %%
canada_df.to_json('modified.json', orient='records', lines=True)

# %%
test1 = pd.read_json('modified.json', orient='records', lines=True)

# %%
test1.head()
# Out:
#                                           MainBranch Hobbyist   Age  \
# 0                     I am a developer by profession      Yes   NaN
# 1                     I am a developer by profession       No   NaN
# 2                        I code primarily as a hobby      Yes   NaN
# 3                     I am a developer by profession      Yes  25.0
# 4  I used to be a developer by profession, but no...      Yes  31.0
#
#   Age1stCode CompFreq  CompTotal  SalaryUSD Country    CurrencyDesc  \
# 0         13  Monthly        NaN        NaN  Canada   European Euro
# 1         19     None        NaN        NaN  Canada  Pound sterling
# 2         15     None        NaN        NaN  Canada            None
# 3         18     None        NaN        NaN  Canada    Albanian lek
# 4         16     None        NaN        NaN  Canada            None
#
#   CurrencySymbol DatabaseDesireNextYear  \
# 0            EUR   Microsoft SQL Server
# 1            GBP                   None
# ...
